# %%
# Librerías
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math


###############################################################################

# Data Preparation

###############################################################################

# Dataset -> https://www.kaggle.com/ntnu-testimon/paysim1
#dataset = pd.read_csv('paysim.csv')
#dataset = dataset.sort_values(by='isFraud', ascending=False)
#dataset.reset_index(drop=True, inplace=True)
#d = dataset[dataset['isFraud']==1]
#dataset = dataset.iloc[0:len(d)*2]
#dataset.to_csv('paysim_reduced.csv')

dataset = pd.read_csv('BD_M7T3_ANN/paysim_reduced.csv')

# Data Preparation
df_aux = pd.get_dummies(dataset['type']).astype('int')
dataset.drop(['type', 'Unnamed: 0', 'nameOrig', 
              'nameDest', 'isFlaggedFraud', 'step',
              'newbalanceOrig', 'newbalanceDest'], axis=1, inplace=True)
dataset = dataset.join(df_aux)

X = dataset.loc[:, dataset.columns != 'isFraud'].values
y = dataset['isFraud'].values

# Train/Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)


###############################################################################

# ANN Build

###############################################################################

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense


def create_nn(n_features, w_in, w_h1, n_var_out, optimizer, lr, momentum, decay):
    """
    Funcion para crear una NN para clasificacion binaria usando 2 HL
    
    """
    
    
    # Initialising the ANN
    model = Sequential()
    
    # First HL
    # [batch_size x n_features] x [n_features x w_in]
    model.add(Dense(units = w_in, input_dim = n_features, 
                    kernel_initializer = 'normal', 
                    activation = 'relu')) 
    # Second HL
    # [batch_size x w_in] x [w_in x w_h1]
    model.add(Dense(units = w_h1, input_dim = w_in, 
                    kernel_initializer = 'normal', 
                    activation = 'relu'))
    
    # Output Layer
    # [batch_size x w_h1] x [w_h1 x w_out]
    model.add(Dense(units = n_var_out, 
                    kernel_initializer = 'normal', 
                    activation = 'sigmoid')) 
    
    # Compile Model
    # Loss Function -> Cross Entropy (Binary)
    # Optimizer -> sgd, adam...
    if optimizer == 'sgd':
        keras.optimizers.SGD(lr=lr, momentum=momentum, decay=decay, nesterov=False)
        model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
    else:
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        
    return model



## fix random seed for reproducibility
#from tensorflow import set_random_seed
#from numpy.random import seed
#value = 7
#seed(value)
#set_random_seed(value)


# Parametros
n_features = np.shape(X_train)[1]
w_in = 12
w_h1 = 8
n_var_out = 1
batch_size = 100
nb_epochs = 100
optimizer = 'adam'
lr = 0.1
momentum = 0.01
decay = 0.0

# Create NN
model = create_nn(n_features, w_in, w_h1, n_var_out, optimizer, lr, momentum, decay)
    
# Fitting the ANN to the Training set
model.fit(X_train, y_train, batch_size = batch_size, epochs = nb_epochs)

    
###############################################################################

# ANN Predictions

###############################################################################

# Predict
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)

# Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# Epoch 1/100
# 124/124 [==============================] - 0s 713us/step - loss: 0.6796 - accuracy: 0.7216
# Epoch 2/100
# 124/124 [==============================] - 0s 746us/step - loss: 0.4827 - accuracy: 0.8188
# Epoch 3/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.3492 - accuracy: 0.8332
# Epoch 4/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.3295 - accuracy: 0.8303
# Epoch 5/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.3059 - accuracy: 0.8444
# Epoch 6/100
# 124/124 [==============================] - 0s 957us/step - loss: 0.3021 - accuracy: 0.8442
# Epoch 7/100
# 124/124 [==============================] - 0s 1ms/step - loss: 0.2922 - accuracy: 0.8490
# Epoch 8/100
# 124/124 [==============================] - 0s 860us/step - loss: 0.2807 - accuracy: 0.8507
# Epoch 9/100
# 124/124 [==============================] - 0s 657us/step - loss: 0.2667 - accuracy: 0.8691
# Epoch 10/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.2627 - accuracy: 0.8684
# Epoch 11/100
# 124/124 [==============================] - 0s 657us/step - loss: 0.2530 - accuracy: 0.8726
# Epoch 12/100
# 124/124 [==============================] - 0s 657us/step - loss: 0.2536 - accuracy: 0.8703
# Epoch 13/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.2444 - accuracy: 0.8805
# Epoch 14/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.2413 - accuracy: 0.8817
# Epoch 15/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.2246 - accuracy: 0.8936
# Epoch 16/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.2170 - accuracy: 0.8996
# Epoch 17/100
# 124/124 [==============================] - 0s 665us/step - loss: 0.2181 - accuracy: 0.9022
# Epoch 18/100
# 124/124 [==============================] - 0s 665us/step - loss: 0.2091 - accuracy: 0.9059
# Epoch 19/100
# 124/124 [==============================] - 0s 681us/step - loss: 0.2061 - accuracy: 0.9114
# Epoch 20/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.2042 - accuracy: 0.9128
# Epoch 21/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.2007 - accuracy: 0.9122
# Epoch 22/100
# 124/124 [==============================] - 0s 706us/step - loss: 0.1977 - accuracy: 0.9131
# Epoch 23/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.1961 - accuracy: 0.9155
# Epoch 24/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1838 - accuracy: 0.9211
# Epoch 25/100
# 124/124 [==============================] - 0s 697us/step - loss: 0.1896 - accuracy: 0.9198
# Epoch 26/100
# 124/124 [==============================] - 0s 714us/step - loss: 0.1870 - accuracy: 0.9258
# Epoch 27/100
# 124/124 [==============================] - 0s 811us/step - loss: 0.1717 - accuracy: 0.9302
# Epoch 28/100
# 124/124 [==============================] - 0s 705us/step - loss: 0.1764 - accuracy: 0.9252
# Epoch 29/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1694 - accuracy: 0.9268
# Epoch 30/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1708 - accuracy: 0.9292
# Epoch 31/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1613 - accuracy: 0.9316
# Epoch 32/100
# 124/124 [==============================] - 0s 714us/step - loss: 0.1716 - accuracy: 0.9303
# Epoch 33/100
# 124/124 [==============================] - 0s 697us/step - loss: 0.1543 - accuracy: 0.9351
# Epoch 34/100
# 124/124 [==============================] - 0s 714us/step - loss: 0.1560 - accuracy: 0.9370
# Epoch 35/100
# 124/124 [==============================] - 0s 689us/step - loss: 0.1511 - accuracy: 0.9400
# Epoch 36/100
# 124/124 [==============================] - 0s 981us/step - loss: 0.1496 - accuracy: 0.9404
# Epoch 37/100
# 124/124 [==============================] - 0s 973us/step - loss: 0.1492 - accuracy: 0.9399
# Epoch 38/100
# 124/124 [==============================] - 0s 965us/step - loss: 0.1471 - accuracy: 0.9386
# Epoch 39/100
# 124/124 [==============================] - 0s 973us/step - loss: 0.1509 - accuracy: 0.9432
# Epoch 40/100
# 124/124 [==============================] - 0s 673us/step - loss: 0.1437 - accuracy: 0.9469
# Epoch 41/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1404 - accuracy: 0.9444
# Epoch 42/100
# 124/124 [==============================] - 0s 689us/step - loss: 0.1447 - accuracy: 0.9422
# Epoch 43/100
# 124/124 [==============================] - 0s 705us/step - loss: 0.1476 - accuracy: 0.9437
# Epoch 44/100
# 124/124 [==============================] - 0s 697us/step - loss: 0.1368 - accuracy: 0.9436
# Epoch 45/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.1429 - accuracy: 0.9473
# Epoch 46/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1346 - accuracy: 0.9491
# Epoch 47/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1359 - accuracy: 0.9491
# Epoch 48/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.1288 - accuracy: 0.9521
# Epoch 49/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1321 - accuracy: 0.9515
# Epoch 50/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1328 - accuracy: 0.9477
# Epoch 51/100
# 124/124 [==============================] - 0s 787us/step - loss: 0.1332 - accuracy: 0.9486
# Epoch 52/100
# 124/124 [==============================] - 0s 795us/step - loss: 0.1364 - accuracy: 0.9500
# Epoch 53/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1245 - accuracy: 0.9536
# Epoch 54/100
# 124/124 [==============================] - 0s 705us/step - loss: 0.1272 - accuracy: 0.9502
# Epoch 55/100
# 124/124 [==============================] - 0s 705us/step - loss: 0.1222 - accuracy: 0.9567
# Epoch 56/100
# 124/124 [==============================] - 0s 697us/step - loss: 0.1222 - accuracy: 0.9556
# Epoch 57/100
# 124/124 [==============================] - 0s 714us/step - loss: 0.1192 - accuracy: 0.9555
# Epoch 58/100
# 124/124 [==============================] - 0s 778us/step - loss: 0.1176 - accuracy: 0.9559
# Epoch 59/100
# 124/124 [==============================] - 0s 770us/step - loss: 0.1234 - accuracy: 0.9535
# Epoch 60/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1208 - accuracy: 0.9565
# Epoch 61/100
# 124/124 [==============================] - 0s 787us/step - loss: 0.1175 - accuracy: 0.9578
# Epoch 62/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1194 - accuracy: 0.9580
# Epoch 63/100
# 124/124 [==============================] - 0s 770us/step - loss: 0.1158 - accuracy: 0.9581
# Epoch 64/100
# 124/124 [==============================] - 0s 778us/step - loss: 0.1220 - accuracy: 0.9571
# Epoch 65/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1262 - accuracy: 0.9611
# Epoch 66/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1179 - accuracy: 0.9563
# Epoch 67/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1122 - accuracy: 0.9613
# Epoch 68/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1150 - accuracy: 0.9585
# Epoch 69/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1104 - accuracy: 0.9630
# Epoch 70/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.1154 - accuracy: 0.9644
# Epoch 71/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1104 - accuracy: 0.9623
# Epoch 72/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1194 - accuracy: 0.9625
# Epoch 73/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1240 - accuracy: 0.9594
# Epoch 74/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1143 - accuracy: 0.9605
# Epoch 75/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1109 - accuracy: 0.9611
# Epoch 76/100
# 124/124 [==============================] - 0s 770us/step - loss: 0.1102 - accuracy: 0.9624
# Epoch 77/100
# 124/124 [==============================] - 0s 778us/step - loss: 0.1093 - accuracy: 0.9641
# Epoch 78/100
# 124/124 [==============================] - 0s 787us/step - loss: 0.1096 - accuracy: 0.9616
# Epoch 79/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1023 - accuracy: 0.9667
# Epoch 80/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1106 - accuracy: 0.9626
# Epoch 81/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1160 - accuracy: 0.9597
# Epoch 82/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1057 - accuracy: 0.9667
# Epoch 83/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1072 - accuracy: 0.9661
# Epoch 84/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1115 - accuracy: 0.9614
# Epoch 85/100
# 124/124 [==============================] - 0s 722us/step - loss: 0.1059 - accuracy: 0.9643
# Epoch 86/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.0971 - accuracy: 0.9681
# Epoch 87/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1001 - accuracy: 0.9681
# Epoch 88/100
# 124/124 [==============================] - 0s 746us/step - loss: 0.1054 - accuracy: 0.9629
# Epoch 89/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1072 - accuracy: 0.9588
# Epoch 90/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1048 - accuracy: 0.9662
# Epoch 91/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1069 - accuracy: 0.9644
# Epoch 92/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.1109 - accuracy: 0.9650
# Epoch 93/100
# 124/124 [==============================] - 0s 746us/step - loss: 0.1132 - accuracy: 0.9656
# Epoch 94/100
# 124/124 [==============================] - 0s 738us/step - loss: 0.0986 - accuracy: 0.9679
# Epoch 95/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.0942 - accuracy: 0.9701
# Epoch 96/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1016 - accuracy: 0.9683
# Epoch 97/100
# 124/124 [==============================] - 0s 754us/step - loss: 0.1009 - accuracy: 0.9659
# Epoch 98/100
# 124/124 [==============================] - 0s 746us/step - loss: 0.1051 - accuracy: 0.9681
# Epoch 99/100
# 124/124 [==============================] - 0s 762us/step - loss: 0.1059 - accuracy: 0.9691
# Epoch 100/100
# 124/124 [==============================] - 0s 730us/step - loss: 0.1005 - accuracy: 0.9713
# array([[1940,  132],
#        [  16, 2019]], dtype=int64)
